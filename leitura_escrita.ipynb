# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-935458a3-c89b-4109-9eae-5cbb70a92e23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-935458a3-c89b-4109-9eae-5cbb70a92e23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-934e6723-a004-414c-b0ea-c97048c678d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-934e6723-a004-414c-b0ea-c97048c678d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("YoutubeAnalysis").getOrCreate()

# %%
# 1. Ler o arquivo videos-stats.csv sem inferir esquema
videos_df = spark.read.csv("/content/videos-stats.csv", header=True, inferSchema=False)

# 2. Visualizar os primeiros 8 registros
videos_df.show(8)

# 3. Visualizar o esquema
videos_df.printSchema()

# 4. Ler novamente inferindo o esquema
videos_df_infer = spark.read.csv("/content/videos-stats.csv", header=True, inferSchema=True)
videos_df_infer.printSchema()

# 5. Salvar como parquet com cabeçalho
videos_df_infer.write.mode("overwrite").option("header", True).parquet("/content/videos-parquet")

# 6. Ler e visualizar parquet
videos_parquet = spark.read.parquet("/content/videos-parquet")
videos_parquet.show(8)

# 7. Salvar como tabela tb_videos
videos_parquet.write.mode("overwrite").saveAsTable("tb_videos")

# 8. Listar tabelas do catálogo Spark
spark.catalog.listTables()

# 9. Usar Spark SQL para ler a tabela tb_videos
spark.sql("SELECT * FROM tb_videos LIMIT 8").show()

# 10. Ler comments.csv inferindo esquema
comments_df = spark.read.csv("/content/comments.csv", header=True, inferSchema=True)
comments_df.show(8)
comments_df.printSchema()

# 11. Salvar comments como parquet
comments_df.write.mode("overwrite").option("header", True).parquet("/content/comments-parquet")
# Out:
# +---+--------------------+-----------+------------+-------+--------+--------+---------+
# |_c0|               Title|   Video ID|Published At|Keyword|   Likes|Comments|    Views|
# +---+--------------------+-----------+------------+-------+--------+--------+---------+
# |  0|Apple Pay Is Kill...|wAZZ-UWGVHI|  2022-08-23|   tech|  3407.0|   672.0| 135612.0|
# |  1|The most EXPENSIV...|b3x28s61q3c|  2022-08-24|   tech| 76779.0|  4306.0|1758063.0|
# |  2|My New House Gami...|4mgePWWCAmA|  2022-08-23|   tech| 63825.0|  3338.0|1564007.0|
# |  3|Petrol Vs Liquid ...|kXiYSI7H2b0|  2022-08-23|   tech| 71566.0|  1426.0| 922918.0|
# |  4|Best Back to Scho...|ErMwWXQxHp0|  2022-08-08|   tech| 96513.0|  5155.0|1855644.0|
# |  5|Brewmaster Answer...|18fwz9Itbvo|  2021-11-05|   tech| 33570.0|  1643.0| 943119.0|
# |  6|Tech Monopolies: ...|jXf04bhcjbg|  2022-06-13|   tech|135047.0|  9367.0|5937790.0|
# |  7|I bought the STRA...|2TqOmtTAMRY|  2022-08-07|   tech|216935.0| 12605.0|4782514.0|
# ...

# %%
videos_df_infer.write.mode("overwrite").option("header", True).parquet("/content/videos-parquet")
comments_df.write.mode("overwrite").option("header", True).parquet("/content/comments-parquet")

# %%
spark.read.parquet("/content/videos-parquet").show(8)
spark.read.parquet("/content/comments-parquet").show(8)
# Out:
# +---+--------------------+-----------+------------+-------+--------+--------+---------+
# |_c0|               Title|   Video ID|Published At|Keyword|   Likes|Comments|    Views|
# +---+--------------------+-----------+------------+-------+--------+--------+---------+
# |  0|Apple Pay Is Kill...|wAZZ-UWGVHI|  2022-08-23|   tech|  3407.0|   672.0| 135612.0|
# |  1|The most EXPENSIV...|b3x28s61q3c|  2022-08-24|   tech| 76779.0|  4306.0|1758063.0|
# |  2|My New House Gami...|4mgePWWCAmA|  2022-08-23|   tech| 63825.0|  3338.0|1564007.0|
# |  3|Petrol Vs Liquid ...|kXiYSI7H2b0|  2022-08-23|   tech| 71566.0|  1426.0| 922918.0|
# |  4|Best Back to Scho...|ErMwWXQxHp0|  2022-08-08|   tech| 96513.0|  5155.0|1855644.0|
# |  5|Brewmaster Answer...|18fwz9Itbvo|  2021-11-05|   tech| 33570.0|  1643.0| 943119.0|
# |  6|Tech Monopolies: ...|jXf04bhcjbg|  2022-06-13|   tech|135047.0|  9367.0|5937790.0|
# |  7|I bought the STRA...|2TqOmtTAMRY|  2022-08-07|   tech|216935.0| 12605.0|4782514.0|
# ...

# %%
spark.read.parquet("/content/videos-parquet").write.mode("overwrite").saveAsTable("tb_videos")

# %%
spark.catalog.listTables()
spark.sql("SELECT * FROM tb_videos LIMIT 8").show()
# Out:
# +---+--------------------+-----------+------------+-------+--------+--------+---------+
# |_c0|               Title|   Video ID|Published At|Keyword|   Likes|Comments|    Views|
# +---+--------------------+-----------+------------+-------+--------+--------+---------+
# |  0|Apple Pay Is Kill...|wAZZ-UWGVHI|  2022-08-23|   tech|  3407.0|   672.0| 135612.0|
# |  1|The most EXPENSIV...|b3x28s61q3c|  2022-08-24|   tech| 76779.0|  4306.0|1758063.0|
# |  2|My New House Gami...|4mgePWWCAmA|  2022-08-23|   tech| 63825.0|  3338.0|1564007.0|
# |  3|Petrol Vs Liquid ...|kXiYSI7H2b0|  2022-08-23|   tech| 71566.0|  1426.0| 922918.0|
# |  4|Best Back to Scho...|ErMwWXQxHp0|  2022-08-08|   tech| 96513.0|  5155.0|1855644.0|
# |  5|Brewmaster Answer...|18fwz9Itbvo|  2021-11-05|   tech| 33570.0|  1643.0| 943119.0|
# |  6|Tech Monopolies: ...|jXf04bhcjbg|  2022-06-13|   tech|135047.0|  9367.0|5937790.0|
# |  7|I bought the STRA...|2TqOmtTAMRY|  2022-08-07|   tech|216935.0| 12605.0|4782514.0|
# ...
